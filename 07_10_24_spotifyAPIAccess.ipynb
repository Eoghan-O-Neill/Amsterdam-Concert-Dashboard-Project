gcSSAlYkECXEG0AABAAgEEABQik7MAQQBmy1F4sm0ZWmBaPmC57TAMkCIAA.YAAAAAAAAAAA,key:d769f189-717f-4da8-9078-32e69a757587}; _parsely_session={^%^22sid^%^22:1^%^2C^%^22surl^%^22:^%^22https://ra.co/^%^22^%^2C^%^22sref^%^22:^%^22https://www.google.com/^%^22^%^2C^%^22sts^%^22:1728321295951^%^2C^%^22slts^%^22:0}; _parsely_visitor={^%^22id^%^22:^%^22pid=7d705b7c7cc1bd37c3cc2ca3142f56f9^%^22^%^2C^%^22session_count^%^22:1^%^2C^%^22last_session_ts^%^22:1728321295951}; _hjSessionUser_2885683=eyJpZCI6IjA0NTIyYzkxLTA3ODEtNTkxMy1hZDhjLTFkOWJiYTFjMTAxYiIsImNyZWF0ZWQiOjE3MjgzMjEyOTY3ODAsImV4aXN0aW5nIjp0cnVlfQ==; _hjSession_2885683=eyJpZCI6ImQwMmI5OTE5LWYwMjQtNGI5NS05NDA1LWVlMjE4YjhhZTgxNCIsImMiOjE3MjgzMjEyOTY3ODIsInMiOjAsInIiOjAsInNiIjowLCJzciI6MCwic2UiOjAsImZzIjoxLCJzcCI6MH0=; _ga=GA1.2.693116345.1728321297; _gid=GA1.2.431728491.1728321298; _ga_2TS7X268TH=GS1.1.1728321296.1.1.1728321820.57.0.0; _gat_UA-313318-1=1',
    'Sec-Fetch-Dest': 'empty',
    'Sec-Fetch-Mode': 'cors',
    'Sec-Fetch-Site': 'same-origin',
    'Priority': 'u=4',
    # Requests doesn't support trailers
    # 'TE': 'trailers',
}

# %%
def eventURLGen(page):
    cookies = {
        'datadome': '3RRjpOb8bpd3sRROv2KplmK2cfUr_5Al~VCyQMoqUhqiO_p9o1T3bB1J6MIXBkogCfGJCxMsQHIZGNbMOM685U8UDqdJ6EjDie4IwoJt0w7ypsTHhhyse_647FfZHrm3',
        'ravelinDeviceId': 'rjs-08d9d67b-5149-46dd-b94f-21ec94bb9c75',
        'genre': '...',
        'ra_mp_experimentdata': '^%^5B^%^22Hide^%^20interested^%^20(roll^%^20call)^%^20count^%^3Adisabled^%^22^%^2C^%^22Promoter^%^20ticket^%^20fee^%^20type^%^3Adisabled^%^22^%^5D',
        'ra_content_language': 'en',
        'ravelinSessionId': 'rjs-08d9d67b-5149-46dd-b94f-21ec94bb9c75:6426d3ec-af25-4c6f-a83c-ecee07944558',
        'lvl1': 'web',
        'lvl2': 'fbf9561bc14d197e',
        'ASP.NET_SessionId': 'uwoftz5zw2j3vjbsav54cp1x',
        'sid': 'b1d4dffb-e8e3-4164-993d-f1eef1d74f27',
        'events_area_id': '29',
        'iterable': '^%^7B^%^22distinctId^%^22^%^3A^%^22d123867b-de2f-46cc-a4c1-ab77d7139e79^%^22^%^7D',
        'ra_mp_userid': '192424309784d-0d33497a512326-f555720-240000-19242430979126',
3222.3223.3225.3226.3227.3228.3230.3231.3234.3235.3236.3237.3238.3240.3244.3245.3250.3251.3253.3257.3260.3270.3272.3281.3288.3290.3292.3293.3296.3299.3300.3306.3307.3309.3314.3315.3316.3318.3324.3328.3330.3331.3531.3731.3831.4131.4531.4631.4731.4831.5231.6931.7235.7831.7931.8931.9731.10231.10631.10831.11031.11531.12831.13632.13731.14237.14332.15731.16831.16931.21233.23031.25731.25931.26031.26831.27731.27831.28031.28731.28831.29631.31631.32531.33631.34231.34631~dv.,CMP:CQGH20AQGH20AF2ACBENBKFsAP_gAEPgAAAAKhNV_G__bWlr8X73aftkeY1P9_h77sQxBhfJE-4FzLvW_JwXx2ExNA36tqIKmRIAu3bBIQNlGJDUTVCgaogVryDMaE2coTNKJ6BkiFMRM2dYCF5vm4tj-QCY5vr991dx2B-t7dr83dzyz4VHn3a5_2a0WJCdA5-tDfv9bROb-9IOd_x8v4v8_F_rE2_eT1l_tWvp7D9-cts7_XW89_fff_9Ln_-uB_-_3_sFQACTDQqIAyyJCQg0DCCBACoKwgIoEAAAAJA0QEAJgwKdgYBLrCRACAFAAMEAIAAQZAAgAAEgAQiACAAoEAAEAgUAAYAEAwEADAwABgAsBAIAAQHQMUwIIBAsAEjMiIUwIQgEggJbKhBIAgQVwhCLPAogERMFAAACQAVgACAsFgcSSAlYkECXEG0AABAAgEEABQik7MAQQBmy1F4sm0ZWmBaPmC57TAMkCIAA.YAAAAAAAAAAA,key:d769f189-717f-4da8-9078-32e69a757587}',
        '_parsely_session': '{^%^22sid^%^22:1^%^2C^%^22surl^%^22:^%^22https://ra.co/^%^22^%^2C^%^22sref^%^22:^%^22https://www.google.com/^%^22^%^2C^%^22sts^%^22:1728321295951^%^2C^%^22slts^%^22:0}',
        '_parsely_visitor': '{^%^22id^%^22:^%^22pid=7d705b7c7cc1bd37c3cc2ca3142f56f9^%^22^%^2C^%^22session_count^%^22:1^%^2C^%^22last_session_ts^%^22:1728321295951}',
        '_hjSessionUser_2885683': 'eyJpZCI6IjA0NTIyYzkxLTA3ODEtNTkxMy1hZDhjLTFkOWJiYTFjMTAxYiIsImNyZWF0ZWQiOjE3MjgzMjEyOTY3ODAsImV4aXN0aW5nIjp0cnVlfQ==',
        '_hjSession_2885683': 'eyJpZCI6ImQwMmI5OTE5LWYwMjQtNGI5NS05NDA1LWVlMjE4YjhhZTgxNCIsImMiOjE3MjgzMjEyOTY3ODIsInMiOjAsInIiOjAsInNiIjowLCJzciI6MCwic2UiOjAsImZzIjoxLCJzcCI6MH0=',
        '_ga': 'GA1.2.693116345.1728321297',
        '_gid': 'GA1.2.431728491.1728321298',
        '_ga_2TS7X268TH': 'GS1.1.1728321296.1.1.1728321820.57.0.0',
        '_gat_UA-313318-1': '1',
    }

    data = {
        "operationName": "GET_EVENT_LISTINGS",
        "variables": {
            "filters": {
                "areas": {
                    "eq": 29
                },
                "listingDate": {
                    "gte": "2024-10-07"
                }
            },
            "filterOptions": {
                "genre": True,
                "eventType": True
            },
            "pageSize": 20,
            "page": page,
            "sort": {
                "listingDate": {
                    "order": "ASCENDING"
                },
                "score": {
                    "order": "DESCENDING"
                },
                "titleKeyword": {
                    "order": "ASCENDING"
                }
            },
            "includeBumps": True,
            "areaId": 29,
            "dateRange": {
                "startDate": "2024-10-07"
            }
        },
        "query": """
            query GET_EVENT_LISTINGS($filters: FilterInputDtoInput, $filterOptions: FilterOptionsInputDtoInput, $page: Int, $pageSize: Int, $sort: SortInputDtoInput, $includeBumps: Boolean!, $areaId: ID, $dateRange: DateRangeInput) {
                eventListings(
                    filters: $filters
                    filterOptions: $filterOptions
                    pageSize: $pageSize
                    page: $page
                    sort: $sort
                ) {
                    data {
                        id
                        listingDate
                        event {
                            ...eventListingsFields
                            artists {
                                id
                                name
                                __typename
                            }
                            __typename
                        }
                        __typename
                    }
                    filterOptions {
                        genre {
                            label
                            value
                            count
                            __typename
                        }
                        eventType {
                            value
                            count
                            __typename
                        }
                        location {
                            value {
                                from
                                to
                                __typename
                            }
                            count
                            __typename
                        }
                        __typename
                    }
                    totalResults
                    __typename
                }
                bumps(areaId: $areaId, dateRange: $dateRange) @include(if: $includeBumps) {
                    bumpDecision {
                        id
                        date
                        eventId
                        clickUrl
                        impressionUrl
                        event {
                            ...eventListingsFields
                            artists {
                                id
                                name
                                __typename
                            }
                            __typename
                        }
                        __typename
                    }
                    cursor
                    __typename
                }
            }

            fragment eventListingsFields on Event {
                id
                date
                startTime
                endTime
                title
                contentUrl
                flyerFront
                isTicketed
                interestedCount
                isSaved
                isInterested
                queueItEnabled
                newEventForm
                images {
                    id
                    filename
                    alt
                    type
                    crop
                    __typename
                }
                pick {
                    id
                    blurb
                    __typename
                }
                venue {
                    id
                    name
                    contentUrl
                    live
                    __typename
                }
            }
        """
    }

    return requests.post('https://ra.co/graphql', impersonate = "chrome120", cookies=cookies, headers=headers, json = data)

# %%
def xtraInfoGen(id_):
    cookies = {
        'datadome': 'tCdu9il_a4rkGR3ThqAIYYeAIvmo4aQVSBlBXWDKIWG4Wb0RZMTncnbwy1R32kdc6FGCFKOaYj51nZjArN~SB8LbBWon_u3jSBqzPfwIgrxsINAiu8JkiN52Uv2MVRFy',
        'ravelinDeviceId': 'rjs-08d9d67b-5149-46dd-b94f-21ec94bb9c75',
        'genre': '...',
        'ra_mp_experimentdata': '^%^5B^%^22Hide^%^20interested^%^20(roll^%^20call)^%^20count^%^3Adisabled^%^22^%^2C^%^22Promoter^%^20ticket^%^20fee^%^20type^%^3Adisabled^%^22^%^5D',
        'ra_mp_userid': '192424309784d-0d33497a512326-f555720-240000-19242430979126',
        'CookieScriptConsent': '{googleconsentmap:{ad_storage:targeting,analytics_storage:performance,ad_user_data:targeting,ad_personalization:targeting,functionality_storage:functionality,personalization_storage:functionality,security_storage:functionality},firstpage:https://ra.co/,bannershown:1,action:accept,categories:^[\\unclassified\\,\\targeting\\,\\performance\\,\\functionality\\^],GoogleACString:2~43.46.55.61.70.83.89.93.108.117.122.124.135.143
        '_fbp': 'fb.1.1728387840360.695475422786483806',
        '_gat_UA-313318-1': '1',
    }

    data = {
      "operationName": "GET_EVENT_DETAIL",
      "variables": {
        "id": id_
      },
      "query": """
        query GET_EVENT_DETAIL($id: ID!) {
          event(id: $id) {
            id
            title
            flyerFront
            flyerBack
            content
            cost
            date
            startTime
            endTime
            interestedCount
            lineup
            images {
              id
              filename
              alt
              type
              crop
            }
            venue {
              id
              name
              address
              contentUrl
              live
              area {
                id
                name
                urlName
                country {
                  id
                  name
                  urlCode
                  isoCode
                }
              }
              location {
                latitude
                longitude
              }
            }
            artists {
              id
              name
              contentUrl
            }
            tickets(queryType: AVAILABLE) {
              id
              title
              validType
              onSaleFrom
              priceRetail
              isAddOn
              currency {
                id
                code
              }
            }
            standardTickets: tickets(queryType: AVAILABLE, ticketTierType: TICKETS) {
              id
              validType
            }
            genres {
              id
              name
              slug
            }
          }
        }
      """
    }

    return requests.post('https://ra.co/graphql', impersonate = "chrome120", cookies=cookies, headers=headers, json=data)

# %%
resp = xtraInfoGen(2012082)

# %%
resp = eventURLGen(1)

# %%
data = resp.json()

# %%
data['data']['eventListings']['data']
# Out:
# [{'id': '12012989',
#   'listingDate': '2024-10-07T00:00:00.000',
#   'event': {'id': '2012989',
#    'date': '2024-10-07T00:00:00.000',
#    'startTime': '2024-10-07T23:00:00.000',
#    'endTime': '2024-10-08T04:00:00.000',
#    'title': 'HARD MONDAYS AMSTERDAM - HARD TECHNO NIGHT w/ KRONIKBEATZ',
#    'contentUrl': '/events/2012989',
#    'flyerFront': None,
#    'isTicketed': True,
#    'interestedCount': 29,
#    'isSaved': False,
#    'isInterested': False,
#    'queueItEnabled': False,
#    'newEventForm': True,
#    'images': [{'id': '1994021',
#      'filename': 'https://images.ra.co/ce0d9c781f01471e0d4d9a4ffc88133263092a00.jpg',
#      'alt': None,
#      'type': 'FLYERFRONT',
#      'crop': None,
#      '__typename': 'EventImage'},
#     {'id': '1994022',
#      'filename': 'https://images.ra.co/22ff22106fa614ccc182c0fbab7ed839d3a4f177.jpg',
#      'alt': None,
#      'type': 'FLYERBACK',
#      'crop': None,
#      '__typename': 'EventImage'}],
#    'pick': None,
# ...

# %%
url = urllib.parse.urljoin("https://ra.co/", resp.json()['data']['eventListings']['data'][0]['event']['contentUrl'])

# %%
def dataExtractOuter():
    item = {
        "eventId": data['data']['eventListings']['data'][0]['event']['id'],
        "url": url,
        "title": data['data']['eventListings']['data'][0]['event']['title'],
        "date": data['data']['eventListings']['data'][0]['listingDate'],
        "interested": data['data']['eventListings']['data'][0]['event']['interestedCount'],
        "venueName": data['data']['eventListings']['data'][0]['event']['venue']['name'],
        "venueID": data['data']['eventListings']['data'][0]['event']['venue']['contentUrl'],
        "artists": data['data']['eventListings']['data'][0]['event']['artists']
    }
    return item

# %%
def main():
    items = []
    data = eventUrlGen(page)
    for x in data['data']['eventListings']['data']:
    items.append(dataExtractOuter())
