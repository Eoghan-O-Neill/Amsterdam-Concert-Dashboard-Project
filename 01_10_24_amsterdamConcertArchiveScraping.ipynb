# %%
import requests
from bs4 import BeautifulSoup

# %%
headers = {'User-Agent': "Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:130.0) Gecko/20100101 Firefox/130.0"}

# %%
url = "https://www.concertarchives.org/locations/amsterdam-netherlands?page=1#concert-table"

# %%
r = requests.get(url = url, headers = headers)

# %%
soup = BeautifulSoup(r.content)

# %%
table = soup.findAll("div", attrs = {"class": "table-responsive"})

# %%
table
# Out:
# [<div class="table-responsive">
#  <table class="table table-condensed table-hover">
#  <thead>
#  <tr>
#  <th style="min-width: 100px">Date</th>
#  <th style="min-width: 200px">Concert</th>
#  <th style="min-width: 100px">Venue</th>
#  <th style="min-width: 100px">Location</th>
#  <th></th>
#  </tr>
#  </thead>
#  <tbody>
#  <tr>
#  <td class="table-cell-no-stretch">
#  <span class="">Feb 28, 2026
#  </span>
#  <div class="concert-index-labels">
#  <span class="label label-clear-gold" title="Upcoming Concert">Upcoming</span>
#  <div style="margin-top: 7px">
#  <a href="https://www.stubhub.com/hans-zimmer-amsterdam-tickets-2-28-2026/event/155359519/" rel="nofollow" target="_blank">
#  <span class="label label-success" title="Buy Tickets"><i class="fa fa-ticket"></i> Buy Tickets</span>
#  </a>
#  </div>
#  </div>
#  </td>
#  <td>
#  <span class="">
#  <strong><a href="/concerts/hans-zimmer-c5656e9f-317f-4c4e-bbb1-badc4e8bdc18">Hans Zimmer</a></strong>
#  </span>
#  </td>
#  <td>
# ...

# %%
table
# Out:
# [<div class="table-responsive">
#  <table class="table table-condensed table-hover">
#  <thead>
#  <tr>
#  <th style="min-width: 100px">Date</th>
#  <th style="min-width: 200px">Concert</th>
#  <th style="min-width: 100px">Venue</th>
#  <th style="min-width: 100px">Location</th>
#  <th></th>
#  </tr>
#  </thead>
#  <tbody>
#  <tr>
#  <td class="table-cell-no-stretch">
#  <span class="">Feb 28, 2026
#  </span>
#  <div class="concert-index-labels">
#  <span class="label label-clear-gold" title="Upcoming Concert">Upcoming</span>
#  <div style="margin-top: 7px">
#  <a href="https://www.stubhub.com/hans-zimmer-amsterdam-tickets-2-28-2026/event/155359519/" rel="nofollow" target="_blank">
#  <span class="label label-success" title="Buy Tickets"><i class="fa fa-ticket"></i> Buy Tickets</span>
#  </a>
#  </div>
#  </div>
#  </td>
#  <td>
#  <span class="">
#  <strong><a href="/concerts/hans-zimmer-c5656e9f-317f-4c4e-bbb1-badc4e8bdc18">Hans Zimmer</a></strong>
#  </span>
#  </td>
#  <td>
# ...

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html>
#  <head>
#   <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
#   <title>
#    Amsterdam, North Holland, Netherlands Concerts (Updated for 2024 - 2026) | Concert Archives
#   </title>
#   <meta content="Amsterdam, North Holland, Netherlands Concerts (Updated for 2024 - 2026) | Concert Archives" property="og:title"/>
#   <meta content="Amsterdam, North Holland, Netherlands's concert list along with photos, videos, and setlists of past concerts &amp; performances." property="og:description"/>
#   <meta content="Amsterdam, North Holland, Netherlands's concert list along with photos, videos, and setlists of past concerts &amp; performances." name="description"/>
#   <meta content="https://www.concertarchives.org/image_uploads/photo/image/947831/large_image.jpg" property="og:image"/>
#   <meta content="max-image-preview:large" name="robots"/>
#   <meta content="app-id=1531993239" name="apple-itunes-app"/>
# ...
